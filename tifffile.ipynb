# %%
from tifffile import imread, TiffFile

# %%
filename = 'D:\\tmp\\B2-1-c1.tif'
out = imread(filename)

# %%
tifffile = TiffFile(filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42992\21444122.py in ?()
# ----> 1 tifffile = TiffFile(filename, multifile=True)
#
# d:\Code\image-db-to-ome\.pixi\envs\default\Lib\site-packages\tifffile\tifffile.py in ?(self, file, mode, name, offset, size, omexml, _multifile, _useframes, _parent, **is_flags)
#    4273             if key[:3] == 'is_' and key[3:] in TIFF.FILE_FLAGS:
#    4274                 if value is not None:
#    4275                     setattr(self, key, bool(value))
#    4276             else:
# -> 4277                 raise TypeError(f'unexpected keyword argument: {key}')
#    4278
#    4279         if mode not in {None, 'r', 'r+', 'rb', 'r+b'}:
#    4280             raise ValueError(f'invalid mode {mode!r}')
#
# TypeError: unexpected keyword argument: multifile

# %%
print(tifffile.)
# Out:
# None

# %%
import ome_types

ome = ome_types.from_tiff('D:\\tmp\\B2-1-c1.tif')

print(ome)  # prints the OME object
